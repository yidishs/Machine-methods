# %% [markdown]
# # МЛ Практика 1
# ## Обзор занятий: Чем предстоит заниматься
# Цели сессии:
#
# 1. Ознакомление с основными понятиями машинного обучения и структурой практических занятий.
# 2. Представление доступных наборов данных для последующих упражнений.
# 3. Формирование списка участников и распределение ролей (при необходимости).
# 4. Практическое освоение методов описательного анализа данных.
# 5. Понимание типов данных и их важности в контексте машинного обучения.
# План занятий:
#
# 1. Введение и обзор целей курса.
# 2. Представление наборов данных.
# 3. Формирование списка студентов.
# 4. Совместный разбор выбранного набора данных с обсуждением вопросов.
# 5. Задача 1: Описание набора данных и определение типов данных.
# 6. Пример статистического разбора на основе wine.csv.
# 7. Обсуждение типов переменных и их определения по статистике.
# 8. Вопросы и ответы, обсуждение домашних заданий.

# %% [markdown]
# # Наборы данных по вариантам

# %% [markdown]
# Примеры наборов данных

# %% [markdown]
# 1. https://www.kaggle.com/datasets/nabeelqureshitiii/student-performance-dataset
# 2. https://www.kaggle.com/datasets/navjotkaushal/coffee-sales-dataset
# 3. https://www.kaggle.com/datasets/shamimhasan8/education-inequality-data
# 4. https://www.kaggle.com/datasets/adilshamim8/student-depression-dataset
# 5. https://www.kaggle.com/datasets/navjotkaushal/employees-dataset
# 6. https://www.kaggle.com/datasets/abolfazlchanbary81/hearth
# 7. https://www.kaggle.com/datasets/uciml/student-alcohol-consumption
# 8. https://www.kaggle.com/datasets/uom190346a/sleep-health-and-lifestyle-dataset
# 9. https://www.kaggle.com/datasets/lainguyn123/student-performance-factors
# 10. https://www.kaggle.com/datasets/benroshan/factors-affecting-campus-placement
# 11. https://www.kaggle.com/datasets/datascientistanna/customers-dataset

# %% [markdown]
# ## Описание:
# В этом разделе вы загрузите набор данных wine.csv, ознакомитесь с его структурой и проведёте первичный обзор.

# %%
# установка зависимостей
# !pip install pandas matplotlib seaborn
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (3.10.0)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.12/dist-packages (0.13.2)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (4.60.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (3.2.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
# импортируем библиотеки
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Описание:
# В этом разделе вы загрузите набор данных wine.csv, ознакомитесь с его структурой и проведёте первичный обзор.

# %%
PATH_TO_FILE: str = 'student_performance.csv' # Загрузка набора данных
## p.s. в левой панеле нажать на папку и перетащить туда файл,
## а wince.csv заменить на свой вариант (ПКМ -> копировать путь)

df = pd.read_csv(PATH_TO_FILE) # функция превращение данных из CSV в DataFrame

# %%
# вывод датафрейма
df # p.s. обычно переменную с набором данных называют df, придерживайтесь этого наименования в дальнейшем
# Out:
#         student_id  weekly_self_study_hours  attendance_percentage  \
# 0                1                     18.5                   95.6
# 1                2                     14.0                   80.0
# 2                3                     19.5                   86.3
# 3                4                     25.7                   70.2
# 4                5                     13.4                   81.9
# ...            ...                      ...                    ...
# 190357      190358                     24.6                   75.8
# 190358      190359                      6.1                  100.0
# 190359      190360                     19.1                   79.6
# 190360      190361                      3.9                   90.0
# 190361      190362                     11.3                   93.6
#
#         class_participation  total_score grade
# 0                       3.8         97.9     A
# 1                       2.5         83.9     B
# 2                       5.3        100.0     A
# 3                       7.0        100.0     A
# 4                       6.9         92.0     A
# ...                     ...          ...   ...
# 190357                 10.0        100.0     A
# 190358                  9.8         64.9     C
# 190359                  5.3         84.4     B
# 190360                  6.9         54.2     D
# 190361                  6.6         69.2     C
#
# [190362 rows x 6 columns]

# %%
#df.dropna()

# %%
# Вывод первых 5 строк
df.head()

# вывод 5 последних строк
#df.tail()
# Out:
#    student_id  weekly_self_study_hours  attendance_percentage  \
# 0           1                     18.5                   95.6
# 1           2                     14.0                   80.0
# 2           3                     19.5                   86.3
# 3           4                     25.7                   70.2
# 4           5                     13.4                   81.9
#
#    class_participation  total_score grade
# 0                  3.8         97.9     A
# 1                  2.5         83.9     B
# 2                  5.3        100.0     A
# 3                  7.0        100.0     A
# 4                  6.9         92.0     A

# %%
# Информация о наборе данных
df.info() # инфо о датасете название колонки, сколько не пропущенных, дефолтный тип данных
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 190362 entries, 0 to 190361
# Data columns (total 6 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   student_id               190362 non-null  int64
#  1   weekly_self_study_hours  190362 non-null  float64
#  2   attendance_percentage    190362 non-null  float64
#  3   class_participation      190362 non-null  float64
#  4   total_score              190362 non-null  float64
#  5   grade                    190362 non-null  object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 8.7+ MB

# %%
# Статистический разбор
df.describe() # include=all (вывод включая категориальные)
# Out:
#           student_id  weekly_self_study_hours  attendance_percentage  \
# count  190362.000000            190362.000000          190362.000000
# mean    95181.500000                15.045586              84.710217
# std     54952.920309                 6.897532               9.431963
# min         1.000000                 0.000000              50.000000
# 25%     47591.250000                10.300000              78.300000
# 50%     95181.500000                15.000000              85.000000
# 75%    142771.750000                19.700000              91.800000
# max    190362.000000                40.000000             100.000000
#
#        class_participation    total_score
# count        190362.000000  190362.000000
# mean              5.977154      84.304759
# std               1.953968      15.444357
# min               0.000000       9.400000
# 25%               4.600000      73.900000
# 50%               6.000000      87.500000
# 75%               7.300000     100.000000
# max              10.000000     100.000000

# %%
# преобразование в категориальные
# df.columnName = df.columnName.astype('category')
# or
# df['column Name'] = df['column Name'].astype('category')

# %%
# Вывод колонок в наборе данных
df.columns
# Out:
# Index(['student_id', 'weekly_self_study_hours', 'attendance_percentage',
#        'class_participation', 'total_score', 'grade'],
#       dtype='object')

# %% [markdown]
# ## Определение типов переменных

# %%
# Список столбцов и их типов данных
print(df.dtypes)
# Out:
# student_id                   int64
# weekly_self_study_hours    float64
# attendance_percentage      float64
# class_participation        float64
# total_score                float64
# grade                       object
# dtype: object

# %% [markdown]
# - Числовые переменные обычно имеют тип int64 или float64.
# - Категориальные переменные могут иметь тип object или int (например метки класса)

# %% [markdown]
# ## Статистический разбор данных

# %% [markdown]
# 1. **Посчитайте количество уникальных значений для каждой переменной:**

# %%
# Количество уникальных значений
for column in df.columns:
    print(f'{column}: {df[column].nunique()} уникальных значений')
# Out:
# student_id: 190362 уникальных значений
# weekly_self_study_hours: 401 уникальных значений
# attendance_percentage: 500 уникальных значений
# class_participation: 101 уникальных значений
# total_score: 769 уникальных значений
# grade: 5 уникальных значений

# %% [markdown]
# **⏰ задача**
#
# Определить типы переменных
# - номинальные переменные (не имеют порядка и сравнения)
# - порядковые пиеременные (имеют порядок, но не имеют смысла мат операции)
# - числовые непрерывные переменные (имеют порядок, есть смысл мат операций)
#
# Вывести статистику для числовых и для категоиральных перменных раздельно.
#
# p.s. если существует несколько гипотез к какому типу относительно одна и та же переменной - объяснить почему

# %% [markdown]
# ### **Ответ**
# Номинальные: student_id (данная шкала присваивет номер каждому студенту для идентификации и имеет 1 000 000 уникальных значений, что указывает на номинальный тип)
#
# Порядковые: class_participation (101 уникальное значение указывает на то что оценка студентов варируется от 0 до 100 и данные переменные имеют порядок, то есть чем выше балл тем лучше), grade (данная шкала указывает оценку студента(A, B, C, D, F), на прямую показывая порядок удовлетворенности работой)
#
# Числовые непрерывные: weekly_self_study_hours (данная величина это количество часов, имееющие порядок и над которыми есть смысл проводить математические операции (что не свойственно порядковым)), attendance_percentage (так же как и в weekly_self_study_hours), total_score (тоже)

# %%
#списки столбцов по типам
n_vars = ['student_id']
p_vars = ['class_participation', 'grade']
ch_vars = ['weekly_self_study_hours', 'attendance_percentage', 'total_score']

print("Статистика числовых переменных")
print(df[ch_vars].describe())

print( )

print("Статистика категориальных переменных")
categorical_vars = n_vars + p_vars
print(df[categorical_vars].astype('category').describe(include='all'))
# Out:
# Статистика числовых переменных
#        weekly_self_study_hours  attendance_percentage    total_score
# count            190362.000000          190362.000000  190362.000000
# mean                 15.045586              84.710217      84.304759
# std                   6.897532               9.431963      15.444357
# min                   0.000000              50.000000       9.400000
# 25%                  10.300000              78.300000      73.900000
# 50%                  15.000000              85.000000      87.500000
# 75%                  19.700000              91.800000     100.000000
# max                  40.000000             100.000000     100.000000
#
# Статистика категориальных переменных
#         student_id  class_participation   grade
# count       190362             190362.0  190362
# unique      190362                101.0       5
# top         190362                 10.0       A
# freq             1               4494.0  104489

# %% [markdown]
# ## **4. Визуализация распределения переменных**
#
# ### **Описание:**
# Создайте визуализации для понимания распределения числовых и категориальных переменных.
#
# ### **Шаги:**

# %% [markdown]
# 1. **Гистограмма для числовых переменных:**

# %%
num_cols = ['weekly_self_study_hours', 'attendance_percentage', 'total_score']
fig, axes = plt.subplots(1, len(num_cols), figsize=(6 * len(num_cols), 4))

for ax, col in zip(axes, num_cols):
    sns.histplot(df[col], kde=True, ax=ax)
    ax.set_title(f'Распределение {col}')
    ax.set_xlabel(col)
    ax.set_ylabel('Частота')

plt.tight_layout()
plt.show()

# %% [markdown]
# **задача ⏰**
#
# Описать вывод графиков.
# - Является ли распределение нормальным или отлично от него?
# - Концентрация большинства значений
# - если есть категориальная переменная, то с помощью параметры hue попробовать предсказать значение категориальный переменной (пример с диоксидом серы и типом вина)
#
# p.s. 3-5 самых показательных примеров.

# %% [markdown]
# ### **Ответ**
# *weekly_self_study_hours* - не является нормальным распределением, хоть и приближено к нему. Большинство значений находится в левой части графика, студенты преимущественно занимаюся учебой 15 часов, меньше всего студентов ближе к 40 часов.
#
# *attendance_percentage* - распределение точно не нормальное, нет колокообразной формы и симметрии. Большинство студентов имеет посещаемость 85% или в районе данной отметки.
#
# *total_score* - тоже не нормальное распределение. Студенты преищественно получают 78-95 баллов.
#
# В данных графиках и в следующем задание я не учитывала выбросы в минимальных и максимальных точках, так как данные похожи на некорректные.

# %% [markdown]
# 2. **Столбчатая диаграмма для категориальной переменной `Class`:**

# %%
categorical_vars = ['student_id', 'grade', 'class_participation']
fig, axes = plt.subplots(1, len(categorical_vars), figsize=(6 * len(categorical_vars), 4))

for ax, col in zip(axes, categorical_vars):
    sns.histplot(df[col], kde=True, ax=ax)
    ax.set_title(f'Распределение {col}')
    ax.set_xlabel(col)
    ax.set_ylabel('Частота')


#Использование hue
plt.figure(figsize=(12, 6))
sns.countplot(data=df, x='class_participation', hue='grade')
plt.title('Влияние участия в классе на оценку')
plt.xlabel('Уровень участия в классе')
plt.ylabel('Количество студентов')
plt.legend(title='Оценка')
plt.xticks(rotation=90)

plt.tight_layout()
plt.show()

# %% [markdown]
# **задача ⏰**
#
# Описать вывод графиков.
# - в каких значениях концентрируентся переменная?
# - если есть категориальная переменная, то с помощью параметры hue попробовать предсказать значение категориальный переменной (пример с диоксидом серы и типом вина)

# %% [markdown]
# ### **Ответ**
# *student_id* - равномерное распределение по всему диапозону, так как каждый студент имеет уникальный индетификатор.
#
# *grade* - наиболшая концентрация в оценке А, далее оценки идут на убывание.
#
# *class_participation* - наибольшая концентрация приходится на значение 6.
#
# **Параметр hue** так же представлен выше, из данного графика можно предсказать что: на уровне участия в классе 5.6-6.3 максимальное влияние участия класса на оценку; уровень участия в классе 0.1-0.8 имеют минимальное влияние на оценку; с уровня участия в классе 2.1-5.4 происходит резкий рост влияния на оценку.

# %% [markdown]
# **Боксплот для числовой переменной:**

# %%
num_cols = ['weekly_self_study_hours', 'attendance_percentage', 'total_score']
fig, axes = plt.subplots(1, len(num_cols), figsize=(6 * len(num_cols), 4))

for ax, col in zip(axes, num_cols):
    sns.boxplot(df[col], ax=ax)
    ax.set_title(f'Распределение {col}')
    ax.set_xlabel(col)
    ax.set_ylabel('Частота')

plt.tight_layout()
plt.show()

# %% [markdown]
# **задача ⏰**
#
# Описать вывод графиков.
# - Есть ли выбросы?
# - если есть категориальная переменная, то с помощью параметры hue попробовать предсказать значение категориальный переменной (пример с диоксидом серы и типом вина). Определить различия по медиане

# %% [markdown]
# ### **Ответ**
# *weekly_self_study_hours* - выбросы есть, частота 35-40
#
# *attendance_percentage* - выбросы есть, частота 50-60
#
# *total_score* - выбросы есть, частота 0-38

# %% [markdown]
# **Постройте корреляционную матрицу для всех числовых переменных и визуализируйте её с помощью тепловой карты:**

# %%
# Корреляционная матрица
num_cols = ['weekly_self_study_hours', 'attendance_percentage', 'total_score']
correlation_matrix = df[num_cols].corr()

# Визуализация тепловой карты
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Корреляционная матрица')
plt.show()

# %% [markdown]
# **если ValueError**

# %%
# Если будут ошибки ValueError из-за could not conver string to float
df = df.drop('colName', axis=1)
# найти колонку, из-за которой ничего не получается,
# можно найти по object из df.info()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-2335370813.py in <cell line: 0>()
#       1 # Если будут ошибки ValueError из-за could not conver string to float
# ----> 2 df = df.drop('colName', axis=1)
#       3 # найти колонку, из-за которой ничего не получается,
#       4 # можно найти по object из df.info()
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786         for axis, labels in axes.items():
#    4787             if labels is not None:
# -> 4788                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4789
#    4790         if inplace:
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors, only_slice)
#    4828                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4829             else:
# -> 4830                 new_axis = axis.drop(labels, errors=errors)
#    4831             indexer = axis.get_indexer(new_axis)
#    4832
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    7068         if mask.any():
#    7069             if errors != "ignore":
# -> 7070                 raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071             indexer = indexer[~mask]
#    7072         return self.delete(indexer)
#
# KeyError: "['colName'] not found in axis"

# %% [markdown]
# **задача ⏰**
#
# Интерпертировать полученный результат:
# - Какие переменные не коррелируют?
# - Какие переменные имеют сильную положительную корреляцию?
# - Какие переменные имеют сильную слабую корреляцию?
#
# p.s. сильная корреляция считаем abs(corr_coef) >= 0.7

# %% [markdown]
# ### **Ответ**
# *Не коррелируют*: weekly_self_study_hours с attendance_percentage(значение -0.001, количество часов самостоятельной учебы не связано с процентом посещаемости), attendance_percentage с total_score(значение -0.001, посещаемость занятий не связана с итоговым баллом)
#
# *Сильная положительная корреляция*: total_score с weekly_self_study_hours(значение 0.81, часы самостоятельной учебы сильно влияют на итоговый балл)
#
# *Сильная слабая корреляция*: отсутствует
